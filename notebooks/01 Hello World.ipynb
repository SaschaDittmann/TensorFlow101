# %%
import tensorflow as tf
print(tf.__version__)

# %%
ph = "Hello"
pw = " World!"
phw = ph + pw

print(phw)

# %%
h = tf.constant("Hello")
w = tf.constant(" World!")
hw = h + w

print(hw)

# %%
with tf.Session() as sess:
    ans = sess.run(hw)

print(ans)
